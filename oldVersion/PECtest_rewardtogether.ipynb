# %%
import gym
import math
import random
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from collections import namedtuple, deque
from itertools import count
from PIL import Image

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision.transforms as T
import time

import collections
import copy

#env = gym.make('CartPole-v0').unwrapped

# set up matplotlib
is_ipython = 'inline' in matplotlib.get_backend()
if is_ipython:
    from IPython import display

plt.ion()

# if gpu is to be used
device = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")
Transition = namedtuple('Transition',
                        ('state', 'action', 'next_state', 'reward','content'))


class ReplayMemory(object):

    def __init__(self, capacity):
        self.memory = deque([],maxlen=capacity)

    def push(self, *args):
        """Save a transition"""
        self.memory.append(Transition(*args))

    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)

    def __len__(self):
        return len(self.memory)
class DQN(nn.Module):

    def __init__(self,inputs,outputs):
        super(DQN, self).__init__()
        self.conn1 = nn.Linear(inputs,16)
        self.bn1 = nn.BatchNorm1d(16)
        self.conn2 = nn.Linear(16,8)
        self.bn2 = nn.BatchNorm1d(8)
        self.conn3 = nn.Linear(8, outputs)

    # Called with either one element to determine next action, or a batch
    # during optimization. Returns tensor([[left0exp,right0exp]...]).
    def forward(self, x):
        x = x.float().to(device)
        x = F.relu(self.bn1(self.conn1(x)))
        x = F.relu(self.bn2(self.conn2(x)))
        return self.conn3(x)

    
data_path = '/home/ubuntu/data/dataset/R79619_U200_V5000/'
UIT = pd.read_csv(data_path + 'UIT.csv')
UIT
trainUIT = UIT[UIT['day']<18]
contentNum = len(UIT.i.drop_duplicates())
userNum = len(UIT.u.drop_duplicates())
class ENV(object):
    def __init__(self,userNum,contentNum):
        self.userNum = userNum
        self.contentNum =contentNum

        self.r = np.zeros(shape=(userNum,contentNum),dtype=int)
        self.p = np.full(shape=contentNum,fill_value = 1/userNum)
        self.e = np.zeros(shape=contentNum)
        self.S = np.ones(shape=contentNum,dtype=int)
        self.l_edge = 0.1
        self.l_cp = 1

        self.B = np.full(shape=userNum,fill_value=10,dtype=int)

        self.pipe = collections.OrderedDict()


    #有序字典实现LRU
    def updateEgdeCache(self,action,t):
        for i in np.argwhere(action==1).squeeze(-1):
            if i in self.pipe.keys():
                self.pipe.pop(i)
            elif len(self.pipe) >= 500:
                self.e[self.pipe.popitem(last=False)[0]] = 0
            self.pipe[i] = t
            self.e[i] = 1

    
    def updateEnv(self,u,action,t):

        self.p = ((self.r[u] | action)-self.r[u])*(1/self.userNum) + self.p

        self.r[u] = self.r[u] | action

        self.updateEgdeCache(action,t)

    def getStatus(self):
        return (torch.from_numpy(self.r),
                torch.from_numpy(self.p) , 
                torch.from_numpy(self.e),
                torch.from_numpy(self.S),
                self.l_edge,
                self.l_cp)

    def reset(self):
        self.r = np.zeros(shape=(self.userNum,self.contentNum),dtype=int)
        self.p = np.full(shape=self.contentNum,fill_value = 1/self.userNum)
        self.e = np.zeros(shape=self.contentNum)
        self.S = np.ones(shape=self.contentNum,dtype=int)
        self.l_edge = 0.1
        self.l_cp = 1
        self.B = np.full(shape=self.userNum,fill_value=10,dtype=int)
        self.pipe = collections.OrderedDict()

class UE(object):
    def __init__(self,u,env):
        self.u = u

        self.W = []
        self.v = torch.zeros(size=(env.contentNum,),dtype=int)

        self.Bu = int(env.B[self.u])
        self.contentNum = env.contentNum
        self.userNum = env.userNum

        self.r , self.p , self.e, self.S,self.l_edge, self.l_cp = env.getStatus()

        self.action = torch.zeros(size=(env.contentNum,),dtype=int)
        self.lastAction = self.action

        self.reward = 0
        self.ALPHAh = 0.0005
        self.ALPHAo = 0.5
        self.ALPHAl = 0.5
        self.EPS_START = 0.9
        self.EPS_END = 0.1
        self.EPS_DECAY = 10
        self.t = 0
        
        self.statusFeature = self.statusEmbedding()

    def updateViewContent(self,i):
        self.W.append(i)
        self.v[i] = 1


    def statusEmbedding(self):
        statusFeature = torch.zeros(size=(5,env.contentNum)).to(device)
        
        statusFeature[0] = self.v
        statusFeature[1] = self.r[self.u]
        statusFeature[2] = self.p
        statusFeature[3] = self.e
        statusFeature[4] = self.S

        #statusFeature[5] = status['r']
        return statusFeature.T
    
    def getReward(self,lastru,lastp,ru,p,i,action,S,Bu,l_edge,l_cp,e):

        Rh = - self.ALPHAh * (torch.log(lastru * lastp + (1-lastru) * (1-lastp)) - torch.log(ru * p + (1-ru) * (1-p)))

        Ro =   self.ALPHAo * action[i] * (S[i] / Bu + ( e[i] * l_edge + ( 1-e[i] ) * l_cp ) / S[i])

        Rl =   self.ALPHAl * ( ( 1 - action[i] )  * ( l_cp - ( e[i] * l_edge + ( 1 - e[i] ) * l_cp ) ) ) / S[i]

        Rh[i] = Rh[i] + Ro + Rl


        return  Rh.sum()

    def selectAction(self,env,uit,QNetwork,train,memory):

        self.lastStatusFeature = self.statusFeature
        self.lastAction = self.action
        self.lastp = self.p
        self.lastr = self.r

        self.updateViewContent(uit[1])
        self.r , self.p , self.e, self.S, self.l_edge, self.l_cp = env.getStatus()
        self.statusFeature = self.statusEmbedding()
        
        if train:
            self.reward = self.getReward(self.lastr[self.u],self.lastp,self.r[self.u],self.p,self.W[-1],self.action,self.S,self.Bu,self.l_edge,self.l_cp,self.e)
            lastAction = torch.cat(((1-self.lastAction).unsqueeze(1),self.lastAction.unsqueeze(1)),1)
            memory.push(self.lastStatusFeature, 
                    lastAction.to(device), 
                    self.statusFeature,
                    torch.tensor([self.reward.float()]).to(device),
                    torch.tensor([self.W[-1]]).to(device))
        
        sample = random.random()
        eps_threshold = self.EPS_END + (self.EPS_START - self.EPS_END) *  np.exp(-1. * self.t / self.EPS_DECAY)
        self.t = self.t + 1
        
        self.action = torch.zeros(size=(env.contentNum,),dtype=int)
        self.action[self.W[-1]] = 1
        if  not train or (train and sample > eps_threshold):
            QNetwork.eval()
            with torch.no_grad():
                Q_value = QNetwork(self.statusFeature)
                actionIndex = list((Q_value[:,1]-Q_value[:,0]).argsort()[0:self.Bu])
            QNetwork.train()
        else:
            actionIndex = list(torch.randint(0,self.contentNum,(self.Bu,)))
        if self.W[-1] not in actionIndex:
            actionIndex.pop()
        for index in actionIndex:
            self.action[index] = 1

        env.updateEnv(self.u,self.action.numpy(),uit[2])

        return self.action

BATCH_SIZE = 256
GAMMA = 0.999
EPS_START = 0.9
EPS_END = 0.05
EPS_DECAY = 200


steps_done = 0


def optimize_model():
    if len(memory) < BATCH_SIZE:
        #print(len(memory))
        return 0
    transitions = memory.sample(BATCH_SIZE)
    # Transpose the batch (see https://stackoverflow.com/a/19343/3343043 for
    # detailed explanation). This converts batch-array of Transitions
    # to Transition of batch-arrays.
    batch = Transition(*zip(*transitions))

    # Compute a mask of non-final states and concatenate the batch elements
    # (a final state would've been the one after which simulation ended)
    #non_final_mask = torch.tensor(tuple(map(lambda s: s is not None, batch.next_state)), device=device, dtype=torch.bool)
    #non_final_next_states = torch.cat([s for s in batch.next_state if s is not None])
    state_batch = torch.cat(batch.state)
    action_batch = torch.cat(batch.action)
    reward_batch = torch.cat(batch.reward)
    content_batch = torch.cat(batch.content)
    next_state_batch = torch.cat(batch.next_state)

    # Compute Q(s_t, a) - the model computes Q(s_t), then we select the
    # columns of actions taken. These are the actions which would've been taken
    # for each batch state according to policy_net
    state_action_mask_bacth = action_batch.ge(0.5)
    state_action_values = torch.stack(torch.masked_select(policy_net(state_batch),state_action_mask_bacth).chunk(BATCH_SIZE,dim=0)).sum(dim=1)
    #print(state_action_values,state_action_values.dtype)
    # Compute V(s_{t+1}) for all next states.
    # Expected values of actions for non_final_next_states are computed based
    # on the "older" target_net; selecting their best reward with max(1)[0].
    # This is merged based on the mask, such that we'll have either the expected
    # state value or 0 in case the state was final.
    next_state_values = torch.zeros(BATCH_SIZE, device=device)
    #next_state_values[non_final_mask] = target_net(non_final_next_states).max(1)[0].detach()
    
    def getNextStatusQ(s_batch,c_batch):
        with torch.no_grad():
            Q_value= torch.stack(target_net(s_batch).chunk(BATCH_SIZE,dim=0))
            c = c_batch.chunk(BATCH_SIZE,dim=0)
            action = torch.zeros(size=(BATCH_SIZE,contentNum,2),dtype=int).to(device)
            for b in range(BATCH_SIZE):
                Q_value_sortindex = list((Q_value[b,:,1]-Q_value[b,:,0]).argsort()[0:10])
                i = c[b].squeeze()
                if i not in Q_value_sortindex:
                    Q_value_sortindex.pop()
                action[b,i,1] = 1
                for index in Q_value_sortindex:
                    action[b,index,1] = 1
            action[:,:,0]=1-action[:,:,1]
            action_mask = action.ge(0.5).to(device)
            next_state_values = torch.stack(torch.masked_select(Q_value,action_mask).chunk(BATCH_SIZE,dim=0)).sum(dim=1)

            return next_state_values.float()
    
    next_state_values =  getNextStatusQ(next_state_batch,content_batch)

    # Compute the expected Q values
    expected_state_action_values = (next_state_values * GAMMA) + reward_batch

    # Compute Huber loss
    criterion = nn.SmoothL1Loss()
    loss = criterion(state_action_values.unsqueeze(1), expected_state_action_values.unsqueeze(1))

    # Optimize the model
    optimizer.zero_grad()
    loss.backward()
    for param in policy_net.parameters():
        param.grad.data.clamp_(-1, 1)
    optimizer.step()

    return loss

# %%
# Get screen size so that we can initialize layers correctly based on shape
# returned from AI gym. Typical dimensions at this point are close to 3x40x90
# which is the result of a clamped and down-scaled render buffer in get_screen()
#init_screen = get_screen()
#_, _, screen_height, screen_width = init_screen.shape

# Get number of actions from gym action space
#n_actions = env.action_space.n

policy_net = DQN(5, 2).to(device)
target_net = DQN(5, 2).to(device)
target_net.load_state_dict(policy_net.state_dict())
target_net.eval()

optimizer = optim.Adam(policy_net.parameters())

memory = ReplayMemory(10000)


MODELPATH =  './model_dict/dnn_l0o0_ep'

num_episodes = 20
TARGET_UPDATE = 2
bestReward =  0

env = ENV(userNum,contentNum)
UEs = {}
sumReward = 0
loss = 0
UEHit = np.zeros(userNum)
edgeHit = 0


for i_episode in range(num_episodes):
    # Initialize the environment and state

    for index,trace in trainUIT.iterrows():
        uit = trace.to_numpy()
        if uit[0] not in UEs:
            UEs[uit[0]] = UE(uit[0],env)

        ue = UEs[uit[0]]
        
        actionIndex = np.argwhere(ue.lastAction)
        if uit[1] in actionIndex:
            UEHit[uit[0]] += 1
        elif uit[1] in env.pipe.keys():
            edgeHit += 1

        ue.selectAction(env,uit,policy_net,1,memory)

        sumReward += ue.reward
        
        # Perform one step of the optimization (on the policy network)
        if index % 1000 == 0:
            loss += optimize_model()
        
        if index % 10000 == 0:
            print("Time:",time.asctime( time.localtime(time.time())),"--Episode:",i_episode,"  Index:",index,"  Loss:",float(loss/(index+1)),"  Reward:",sumReward/(index+1),)
            print("UEHitrate:",UEHit.sum()/(index+1)," edgeHitrate",edgeHit/(index+1),"sumHitrate",(edgeHit+UEHit.sum())/(index+1))
            print()
    print("----------------------------------------------------------------")
    print("Time:",time.asctime( time.localtime(time.time())),"--End episode:",i_episode,"  Loss:",loss/(index+1),"  Reward:",sumReward/(index+1))
    print("UEHitrate:",UEHit.sum()/(index+1)," edgeHitrate",edgeHit/(index+1),"sumHitrate",(edgeHit+UEHit.sum())/(index+1))
    print("----------------------------------------------------------------")
    print()
    
    # Update the target network, copying all weights and biases in DQN
    if i_episode % TARGET_UPDATE == 0: 
        if sumReward > bestReward:
            bestLoss = loss
            bestReward = sumReward
            bestUEHit = UEHit
            bestEdgeHit = edgeHit
            torch.save(policy_net.state_dict(),MODELPATH+'{}_'.format(i_episode)+time.strftime("%m%d-%H-%M-%S",time.localtime(time.time())))

        target_net.load_state_dict(policy_net.state_dict())

    env.reset()
    UEs = {}
    sumReward = 0
    loss = 0
    UEHit = np.zeros(userNum)
    edgeHit = 0
# Out:
# Time: Fri Sep 10 19:41:46 2021 --Episode: 0   Index: 0   Loss: 0.0   Reward: tensor(0., dtype=torch.float64)
# UEHitrate: 0.0  edgeHitrate 0.0 sumHitrate 0.0
#
# Time: Fri Sep 10 19:42:15 2021 --Episode: 0   Index: 10000   Loss: 0.8719678521156311   Reward: tensor(0.0002, dtype=torch.float64)
# UEHitrate: 0.0244975502449755  edgeHitrate 0.2725727427257274 sumHitrate 0.2970702929707029
#
# Time: Fri Sep 10 19:42:43 2021 --Episode: 0   Index: 20000   Loss: 0.6689618825912476   Reward: tensor(0.0002, dtype=torch.float64)
# UEHitrate: 0.025948702564871758  edgeHitrate 0.33728313584320785 sumHitrate 0.3632318384080796
#
# Time: Fri Sep 10 19:43:15 2021 --Episode: 0   Index: 30000   Loss: 0.597254753112793   Reward: tensor(0.0002, dtype=torch.float64)
# UEHitrate: 0.023365887803739875  edgeHitrate 0.3677210759641345 sumHitrate 0.3910869637678744
#
# Time: Fri Sep 10 19:43:48 2021 --Episode: 0   Index: 40000   Loss: 0.5815087556838989   Reward: tensor(0.0002, dtype=torch.float64)
# UEHitrate: 0.020949476263093424  edgeHitrate 0.3813404664883378 sumHitrate 0.4022899427514312
#
# Time: Fri Sep 10 19:44:21 2021 --Episode: 0   Index: 50000   Loss: 0.5478572845458984   Reward: tensor(0.0002, dtype=torch.float64)
# UEHitrate: 0.019419611607767846  edgeHitrate 0.3500329993400132 sumHitrate 0.36945261094778103
#
# Time: Fri Sep 10 19:44:49 2021 --Episode: 0   Index: 60000   Loss: 0.49975287914276123   Reward: tensor(0.0002, dtype=torch.float64)
# UEHitrate: 0.020816319728004535  edgeHitrate 0.3214113098115031 sumHitrate 0.3422276295395077
#
# Time: Fri Sep 10 19:45:17 2021 --Episode: 0   Index: 70000   Loss: 0.4423738420009613   Reward: tensor(0.0001, dtype=torch.float64)
# UEHitrate: 0.023356809188440165  edgeHitrate 0.30906701332838105 sumHitrate 0.3324238225168212
#
# Time: Fri Sep 10 19:45:46 2021 --Episode: 0   Index: 80000   Loss: 0.3945987820625305   Reward: tensor(0.0001, dtype=torch.float64)
# UEHitrate: 0.025524680941488232  edgeHitrate 0.3036587042661967 sumHitrate 0.3291833852076849
#
# Time: Fri Sep 10 19:46:14 2021 --Episode: 0   Index: 90000   Loss: 0.35662388801574707   Reward: tensor(0.0001, dtype=torch.float64)
# UEHitrate: 0.027266363707069922  edgeHitrate 0.30157442695081166 sumHitrate 0.3288407906578816
#
# Time: Fri Sep 10 19:46:43 2021 --Episode: 0   Index: 100000   Loss: 0.3263843357563019   Reward: tensor(8.9888e-05, dtype=torch.float64)
# UEHitrate: 0.02912970870291297  edgeHitrate 0.3000469995300047 sumHitrate 0.32917670823291767
#
# Time: Fri Sep 10 19:47:13 2021 --Episode: 0   Index: 110000   Loss: 0.3014032542705536   Reward: tensor(8.1661e-05, dtype=torch.float64)
# UEHitrate: 0.030799720002545432  edgeHitrate 0.30005181771074807 sumHitrate 0.3308515377132935
#
# Time: Fri Sep 10 19:47:44 2021 --Episode: 0   Index: 120000   Loss: 0.2806015908718109   Reward: tensor(7.4451e-05, dtype=torch.float64)
# UEHitrate: 0.032141398821676485  edgeHitrate 0.29816418196515027 sumHitrate 0.33030558078682676
#
# Time: Fri Sep 10 19:48:14 2021 --Episode: 0   Index: 130000   Loss: 0.26221564412117004   Reward: tensor(6.8784e-05, dtype=torch.float64)
# UEHitrate: 0.03242282751671141  edgeHitrate 0.2975130960531073 sumHitrate 0.3299359235698187
#
# Time: Fri Sep 10 19:48:43 2021 --Episode: 0   Index: 140000   Loss: 0.24635186791419983   Reward: tensor(6.3363e-05, dtype=torch.float64)
# UEHitrate: 0.032156913164905966  edgeHitrate 0.294490753637474 sumHitrate 0.32664766680238
#
# Time: Fri Sep 10 19:49:18 2021 --Episode: 0   Index: 150000   Loss: 0.23216107487678528   Reward: tensor(5.8815e-05, dtype=torch.float64)
# UEHitrate: 0.03220645195698695  edgeHitrate 0.2903047313017913 sumHitrate 0.32251118325877826
#
# Time: Fri Sep 10 19:49:51 2021 --Episode: 0   Index: 160000   Loss: 0.2197556048631668   Reward: tensor(5.4657e-05, dtype=torch.float64)
# UEHitrate: 0.0323685476965769  edgeHitrate 0.28710445559715253 sumHitrate 0.3194730032937294
#
# Time: Fri Sep 10 19:50:26 2021 --Episode: 0   Index: 170000   Loss: 0.20846383273601532   Reward: tensor(5.1159e-05, dtype=torch.float64)
# UEHitrate: 0.03272333692154752  edgeHitrate 0.28326892194751796 sumHitrate 0.31599225886906546
#
# ----------------------------------------------------------------
# Time: Fri Sep 10 19:50:33 2021 --End episode: 0   Loss: tensor(0.2064, device='cuda:1', grad_fn=<DivBackward0>)   Reward: tensor(5.0632e-05, dtype=torch.float64)
# UEHitrate: 0.03276446937386174  edgeHitrate 0.2824168087371918 sumHitrate 0.31518127811105356
# ----------------------------------------------------------------
#
# Time: Fri Sep 10 19:50:33 2021 --Episode: 1   Index: 0   Loss: 19.558019638061523   Reward: tensor(0., dtype=torch.float64)
# UEHitrate: 0.0  edgeHitrate 0.0 sumHitrate 0.0
#
# Time: Fri Sep 10 19:51:07 2021 --Episode: 1   Index: 10000   Loss: 0.17281973361968994   Reward: tensor(0.0002, dtype=torch.float64)
# UEHitrate: 0.025797420257974202  edgeHitrate 0.2810718928107189 sumHitrate 0.30686931306869314
#
# Time: Fri Sep 10 19:51:53 2021 --Episode: 1   Index: 20000   Loss: 0.13003087043762207   Reward: tensor(0.0001, dtype=torch.float64)
# UEHitrate: 0.03009849507524624  edgeHitrate 0.2992850357482126 sumHitrate 0.32938353082345884
#
# Time: Fri Sep 10 19:52:39 2021 --Episode: 1   Index: 30000   Loss: 0.1045188382267952   Reward: tensor(0.0001, dtype=torch.float64)
# UEHitrate: 0.03376554114862838  edgeHitrate 0.2980900636645445 sumHitrate 0.3318556048131729
#
# Time: Fri Sep 10 19:53:18 2021 --Episode: 1   Index: 40000   Loss: 0.08750694245100021   Reward: tensor(8.6086e-05, dtype=torch.float64)
# UEHitrate: 0.036849078773030675  edgeHitrate 0.30014249643758906 sumHitrate 0.33699157521061973
#
# Time: Fri Sep 10 19:54:02 2021 --Episode: 1   Index: 50000   Loss: 0.0756351426243782   Reward: tensor(7.3068e-05, dtype=torch.float64)
# UEHitrate: 0.0367992640147197  edgeHitrate 0.2913741725165497 sumHitrate 0.32817343653126935
#
# Time: Fri Sep 10 19:55:00 2021 --Episode: 1   Index: 60000   Loss: 0.06661000847816467   Reward: tensor(6.2725e-05, dtype=torch.float64)
# UEHitrate: 0.036632722787953535  edgeHitrate 0.28029532841119315 sumHitrate 0.3169280511991467
#
# Time: Fri Sep 10 19:55:51 2021 --Episode: 1   Index: 70000   Loss: 0.05974298715591431   Reward: tensor(5.5194e-05, dtype=torch.float64)
# UEHitrate: 0.03657090612991243  edgeHitrate 0.27649605005642774 sumHitrate 0.3130669561863402
#
# Time: Fri Sep 10 19:56:42 2021 --Episode: 1   Index: 80000   Loss: 0.05461621284484863   Reward: tensor(4.8019e-05, dtype=torch.float64)
# UEHitrate: 0.036412044849439384  edgeHitrate 0.27210909863626703 sumHitrate 0.3085211434857064
#
# Time: Fri Sep 10 19:57:33 2021 --Episode: 1   Index: 90000   Loss: 0.05201053246855736   Reward: tensor(4.2724e-05, dtype=torch.float64)
# UEHitrate: 0.0367551471650315  edgeHitrate 0.28006355484939055 sumHitrate 0.3168187020144221
#
# Time: Fri Sep 10 19:58:25 2021 --Episode: 1   Index: 100000   Loss: 0.049048904329538345   Reward: tensor(3.8440e-05, dtype=torch.float64)
# UEHitrate: 0.037169628303716964  edgeHitrate 0.2961970380296197 sumHitrate 0.33336666633333667
#
# Time: Fri Sep 10 19:59:19 2021 --Episode: 1   Index: 110000   Loss: 0.04598712548613548   Reward: tensor(3.5238e-05, dtype=torch.float64)
# UEHitrate: 0.0381360169453005  edgeHitrate 0.309588094653685 sumHitrate 0.3477241115989855
#
# Time: Fri Sep 10 20:00:07 2021 --Episode: 1   Index: 120000   Loss: 0.04334564507007599   Reward: tensor(3.2323e-05, dtype=torch.float64)
# UEHitrate: 0.038824676461029495  edgeHitrate 0.3207973266889443 sumHitrate 0.3596220031499737
#
# Time: Fri Sep 10 20:00:57 2021 --Episode: 1   Index: 130000   Loss: 0.04145914688706398   Reward: tensor(3.0012e-05, dtype=torch.float64)
# UEHitrate: 0.03890739302005369  edgeHitrate 0.3339589695463881 sumHitrate 0.3728663625664418
#
# Time: Fri Sep 10 20:01:39 2021 --Episode: 1   Index: 140000   Loss: 0.03941691294312477   Reward: tensor(2.7820e-05, dtype=torch.float64)
# UEHitrate: 0.03873543760401711  edgeHitrate 0.34297612159913143 sumHitrate 0.38171155920314853
#
# Time: Fri Sep 10 20:02:31 2021 --Episode: 1   Index: 150000   Loss: 0.03794368356466293   Reward: tensor(2.5775e-05, dtype=torch.float64)
# UEHitrate: 0.038493076712821914  edgeHitrate 0.3524509836601089 sumHitrate 0.39094406037293084
#
# Time: Fri Sep 10 20:03:20 2021 --Episode: 1   Index: 160000   Loss: 0.03665105998516083   Reward: tensor(2.3821e-05, dtype=torch.float64)
# UEHitrate: 0.038937256642145986  edgeHitrate 0.3616664895844401 sumHitrate 0.40060374622658607
#
# Time: Fri Sep 10 20:04:05 2021 --Episode: 1   Index: 170000   Loss: 0.03602355718612671   Reward: tensor(2.2269e-05, dtype=torch.float64)
# UEHitrate: 0.03954682619514003  edgeHitrate 0.3682037164487268 sumHitrate 0.4077505426438668
#
# ----------------------------------------------------------------
# Time: Fri Sep 10 20:04:13 2021 --End episode: 1   Loss: tensor(0.0357, device='cuda:1', grad_fn=<DivBackward0>)   Reward: tensor(2.1948e-05, dtype=torch.float64)
# UEHitrate: 0.03959549175797001  edgeHitrate 0.36962580660177 sumHitrate 0.40922129835974
# ----------------------------------------------------------------
#
# Time: Fri Sep 10 20:04:14 2021 --Episode: 2   Index: 0   Loss: 12.153098106384277   Reward: tensor(0., dtype=torch.float64)
# UEHitrate: 0.0  edgeHitrate 0.0 sumHitrate 0.0
#
# Time: Fri Sep 10 20:04:50 2021 --Episode: 2   Index: 10000   Loss: 0.09056778252124786   Reward: tensor(0.0002, dtype=torch.float64)
# UEHitrate: 0.019498050194980503  edgeHitrate 0.26137386261373863 sumHitrate 0.28087191280871915
#
# Time: Fri Sep 10 20:05:28 2021 --Episode: 2   Index: 20000   Loss: 0.09415452927350998   Reward: tensor(0.0001, dtype=torch.float64)
# UEHitrate: 0.024748762561871907  edgeHitrate 0.31468426578671066 sumHitrate 0.3394330283485826
#
# Time: Fri Sep 10 20:06:09 2021 --Episode: 2   Index: 30000   Loss: 0.07649548351764679   Reward: tensor(0.0001, dtype=torch.float64)
# UEHitrate: 0.028732375587480416  edgeHitrate 0.3373887537082097 sumHitrate 0.36612112929569013
#
# Time: Fri Sep 10 20:06:48 2021 --Episode: 2   Index: 40000   Loss: 0.06572996079921722   Reward: tensor(9.1944e-05, dtype=torch.float64)
# UEHitrate: 0.03182420439489013  edgeHitrate 0.357816054598635 sumHitrate 0.38964025899352517
#
# Time: Fri Sep 10 20:07:30 2021 --Episode: 2   Index: 50000   Loss: 0.057796210050582886   Reward: tensor(7.8178e-05, dtype=torch.float64)
# UEHitrate: 0.03373932521349573  edgeHitrate 0.36497270054598907 sumHitrate 0.39871202575948483
#
# Time: Fri Sep 10 20:08:12 2021 --Episode: 2   Index: 60000   Loss: 0.05158473923802376   Reward: tensor(6.6924e-05, dtype=torch.float64)
# UEHitrate: 0.03456609056515725  edgeHitrate 0.37039382676955385 sumHitrate 0.4049599173347111
#
# Time: Fri Sep 10 20:08:54 2021 --Episode: 2   Index: 70000   Loss: 0.04671954736113548   Reward: tensor(5.8907e-05, dtype=torch.float64)
# UEHitrate: 0.03619948286453051  edgeHitrate 0.3828231025271068 sumHitrate 0.4190225853916373
#
# Time: Fri Sep 10 20:09:33 2021 --Episode: 2   Index: 80000   Loss: 0.04210938885807991   Reward: tensor(5.1231e-05, dtype=torch.float64)
# UEHitrate: 0.037024537193285086  edgeHitrate 0.39308258646766914 sumHitrate 0.4301071236609542
#
# Time: Fri Sep 10 20:10:16 2021 --Episode: 2   Index: 90000   Loss: 0.038753390312194824   Reward: tensor(4.5550e-05, dtype=torch.float64)
# UEHitrate: 0.037955133831846316  edgeHitrate 0.3986400151109432 sumHitrate 0.4365951489427895
#
# Time: Fri Sep 10 20:10:58 2021 --Episode: 2   Index: 100000   Loss: 0.036663368344306946   Reward: tensor(4.1106e-05, dtype=torch.float64)
# UEHitrate: 0.03842961570384296  edgeHitrate 0.4023859761402386 sumHitrate 0.44081559184408153
#
# Time: Fri Sep 10 20:11:40 2021 --Episode: 2   Index: 110000   Loss: 0.035291172564029694   Reward: tensor(3.7680e-05, dtype=torch.float64)
# UEHitrate: 0.03949964091235534  edgeHitrate 0.40586903755420406 sumHitrate 0.4453686784665594
#
# Time: Fri Sep 10 20:12:26 2021 --Episode: 2   Index: 120000   Loss: 0.03326879069209099   Reward: tensor(3.4509e-05, dtype=torch.float64)
# UEHitrate: 0.039991333405554955  edgeHitrate 0.4086132615561537 sumHitrate 0.4486045949617086
#
# Time: Fri Sep 10 20:13:18 2021 --Episode: 2   Index: 130000   Loss: 0.03187107294797897   Reward: tensor(3.2014e-05, dtype=torch.float64)
# UEHitrate: 0.03979969384850886  edgeHitrate 0.4155660341074299 sumHitrate 0.4553657279559388
#
# Time: Fri Sep 10 20:14:11 2021 --Episode: 2   Index: 140000   Loss: 0.030672607943415642   Reward: tensor(2.9573e-05, dtype=torch.float64)
# UEHitrate: 0.03957114592038628  edgeHitrate 0.4193970043071121 sumHitrate 0.4589681502274984
#
# Time: Fri Sep 10 20:15:05 2021 --Episode: 2   Index: 150000   Loss: 0.029503896832466125   Reward: tensor(2.7385e-05, dtype=torch.float64)
# UEHitrate: 0.03931973786841421  edgeHitrate 0.42396384024106504 sumHitrate 0.4632835781094793
#
# Time: Fri Sep 10 20:15:55 2021 --Episode: 2   Index: 160000   Loss: 0.028541257604956627   Reward: tensor(2.5329e-05, dtype=torch.float64)
# UEHitrate: 0.0395622527359204  edgeHitrate 0.4298223136105399 sumHitrate 0.4693845663464603
#
# Time: Fri Sep 10 20:16:49 2021 --Episode: 2   Index: 170000   Loss: 0.02785000018775463   Reward: tensor(2.3738e-05, dtype=torch.float64)
# UEHitrate: 0.03967035488026541  edgeHitrate 0.433015099911177 sumHitrate 0.4726854547914424
#
# ----------------------------------------------------------------
# Time: Fri Sep 10 20:16:59 2021 --End episode: 2   Loss: tensor(0.0276, device='cuda:1', grad_fn=<DivBackward0>)   Reward: tensor(2.3391e-05, dtype=torch.float64)
# UEHitrate: 0.03970022634307559  edgeHitrate 0.43381065150730524 sumHitrate 0.4735108778503808
# ----------------------------------------------------------------
#
# Time: Fri Sep 10 20:17:00 2021 --Episode: 3   Index: 0   Loss: 20.8023681640625   Reward: tensor(0., dtype=torch.float64)
# UEHitrate: 0.0  edgeHitrate 0.0 sumHitrate 0.0
#
# Time: Fri Sep 10 20:17:45 2021 --Episode: 3   Index: 10000   Loss: 0.09399347007274628   Reward: tensor(0.0002, dtype=torch.float64)
# UEHitrate: 0.014898510148985102  edgeHitrate 0.21177882211778823 sumHitrate 0.22667733226677333
#
# Time: Fri Sep 10 20:18:31 2021 --Episode: 3   Index: 20000   Loss: 0.11967352777719498   Reward: tensor(0.0001, dtype=torch.float64)
# UEHitrate: 0.02069896505174741  edgeHitrate 0.27818609069546524 sumHitrate 0.29888505574721264
#
# Time: Fri Sep 10 20:19:19 2021 --Episode: 3   Index: 30000   Loss: 0.10403043776750565   Reward: tensor(0.0001, dtype=torch.float64)
# UEHitrate: 0.02579914002866571  edgeHitrate 0.315589480350655 sumHitrate 0.34138862037932066
#
# Time: Fri Sep 10 20:20:09 2021 --Episode: 3   Index: 40000   Loss: 0.08992689847946167   Reward: tensor(9.3414e-05, dtype=torch.float64)
# UEHitrate: 0.028874278143046425  edgeHitrate 0.3488412789680258 sumHitrate 0.37771555711107224
#
# Time: Fri Sep 10 20:20:58 2021 --Episode: 3   Index: 50000   Loss: 0.07773728668689728   Reward: tensor(7.9507e-05, dtype=torch.float64)
# UEHitrate: 0.03109937801243975  edgeHitrate 0.3591128177436451 sumHitrate 0.3902121957560849
#
# Time: Fri Sep 10 20:21:52 2021 --Episode: 3   Index: 60000   Loss: 0.06794440001249313   Reward: tensor(6.7954e-05, dtype=torch.float64)
# UEHitrate: 0.032749454175763734  edgeHitrate 0.36636056065732236 sumHitrate 0.3991100148330861
#
# Time: Fri Sep 10 20:22:44 2021 --Episode: 3   Index: 70000   Loss: 0.06133497878909111   Reward: tensor(5.9691e-05, dtype=torch.float64)
# UEHitrate: 0.033828088170168996  edgeHitrate 0.381837402322824 sumHitrate 0.41566549049299295
#
# Time: Fri Sep 10 20:23:38 2021 --Episode: 3   Index: 80000   Loss: 0.05543377995491028   Reward: tensor(5.1863e-05, dtype=torch.float64)
# UEHitrate: 0.03509956125548431  edgeHitrate 0.39398257521780977 sumHitrate 0.4290821364732941
#
# Time: Fri Sep 10 20:24:29 2021 --Episode: 3   Index: 90000   Loss: 0.0509331077337265   Reward: tensor(4.6187e-05, dtype=torch.float64)
# UEHitrate: 0.03563293741180654  edgeHitrate 0.40081776869145896 sumHitrate 0.43645070610326553
#
# Time: Fri Sep 10 20:25:16 2021 --Episode: 3   Index: 100000   Loss: 0.0472131185233593   Reward: tensor(4.1681e-05, dtype=torch.float64)
# UEHitrate: 0.036199638003619965  edgeHitrate 0.4050159498405016 sumHitrate 0.44121558784412157
#
# Time: Fri Sep 10 20:26:10 2021 --Episode: 3   Index: 110000   Loss: 0.04493826627731323   Reward: tensor(3.8158e-05, dtype=torch.float64)
# UEHitrate: 0.03719057099480914  edgeHitrate 0.40952354978591105 sumHitrate 0.4467141207807202
#
# Time: Fri Sep 10 20:27:03 2021 --Episode: 3   Index: 120000   Loss: 0.041983816772699356   Reward: tensor(3.4989e-05, dtype=torch.float64)
# UEHitrate: 0.03795801701652486  edgeHitrate 0.41274656044532965 sumHitrate 0.4507045774618545
#
# Time: Fri Sep 10 20:27:59 2021 --Episode: 3   Index: 130000   Loss: 0.03966353461146355   Reward: tensor(3.2385e-05, dtype=torch.float64)
# UEHitrate: 0.03786893946969639  edgeHitrate 0.4197813862970285 sumHitrate 0.4576503257667249
#
# Time: Fri Sep 10 20:28:51 2021 --Episode: 3   Index: 140000   Loss: 0.03835989162325859   Reward: tensor(3.0011e-05, dtype=torch.float64)
# UEHitrate: 0.03769973071620917  edgeHitrate 0.4235041178277298 sumHitrate 0.461203848543939
#
# Time: Fri Sep 10 20:29:38 2021 --Episode: 3   Index: 150000   Loss: 0.037063490599393845   Reward: tensor(2.7842e-05, dtype=torch.float64)
# UEHitrate: 0.03747308351277658  edgeHitrate 0.4285104765968227 sumHitrate 0.4659835601095993
#
# Time: Fri Sep 10 20:30:31 2021 --Episode: 3   Index: 160000   Loss: 0.035947613418102264   Reward: tensor(2.5798e-05, dtype=torch.float64)
# UEHitrate: 0.03768101449365942  edgeHitrate 0.43419728626696086 sumHitrate 0.47187830076062026
#
# Time: Fri Sep 10 20:31:21 2021 --Episode: 3   Index: 170000   Loss: 0.03465208783745766   Reward: tensor(2.4135e-05, dtype=torch.float64)
# UEHitrate: 0.038052717336956844  edgeHitrate 0.4372327221604579 sumHitrate 0.4752854394974147
#
# ----------------------------------------------------------------
# Time: Fri Sep 10 20:31:29 2021 --End episode: 3   Loss: tensor(0.0344, device='cuda:1', grad_fn=<DivBackward0>)   Reward: tensor(2.3792e-05, dtype=torch.float64)
# UEHitrate: 0.038117570390369074  edgeHitrate 0.4380000349115284 sumHitrate 0.47611760530189745
# ----------------------------------------------------------------
#
# Time: Fri Sep 10 20:31:30 2021 --Episode: 4   Index: 0   Loss: 8.161093711853027   Reward: tensor(0., dtype=torch.float64)
# UEHitrate: 0.0  edgeHitrate 0.0 sumHitrate 0.0
#
# Time: Fri Sep 10 20:32:14 2021 --Episode: 4   Index: 10000   Loss: 0.05579044669866562   Reward: tensor(0.0002, dtype=torch.float64)
# UEHitrate: 0.013598640135986401  edgeHitrate 0.18988101189881013 sumHitrate 0.2034796520347965
#
# Time: Fri Sep 10 20:32:58 2021 --Episode: 4   Index: 20000   Loss: 0.06839381903409958   Reward: tensor(0.0001, dtype=torch.float64)
# UEHitrate: 0.02134893255337233  edgeHitrate 0.2778861056947153 sumHitrate 0.2992350382480876
#
# Time: Fri Sep 10 20:33:50 2021 --Episode: 4   Index: 30000   Loss: 0.06098569184541702   Reward: tensor(0.0001, dtype=torch.float64)
# UEHitrate: 0.026099130028999034  edgeHitrate 0.31448951701609945 sumHitrate 0.3405886470450985
#
# Time: Fri Sep 10 20:34:41 2021 --Episode: 4   Index: 40000   Loss: 0.05293155834078789   Reward: tensor(9.0773e-05, dtype=torch.float64)
# UEHitrate: 0.029099272518187044  edgeHitrate 0.3423164420889478 sumHitrate 0.3714157146071348
#
# Time: Fri Sep 10 20:35:25 2021 --Episode: 4   Index: 50000   Loss: 0.04532260820269585   Reward: tensor(7.6977e-05, dtype=torch.float64)
# UEHitrate: 0.02973940521189576  edgeHitrate 0.3575728485430291 sumHitrate 0.3873122537549249
#
# Time: Fri Sep 10 20:36:08 2021 --Episode: 4   Index: 60000   Loss: 0.0397203266620636   Reward: tensor(6.6044e-05, dtype=torch.float64)
# UEHitrate: 0.030282828619523007  edgeHitrate 0.36681055315744737 sumHitrate 0.3970933817769704
#
# Time: Fri Sep 10 20:36:54 2021 --Episode: 4   Index: 70000   Loss: 0.03767281025648117   Reward: tensor(5.8276e-05, dtype=torch.float64)
# UEHitrate: 0.03164240510849845  edgeHitrate 0.381537406608477 sumHitrate 0.4131798117169755
#
# Time: Fri Sep 10 20:37:35 2021 --Episode: 4   Index: 80000   Loss: 0.03579564392566681   Reward: tensor(5.0658e-05, dtype=torch.float64)
# UEHitrate: 0.0328620892238847  edgeHitrate 0.39355758053024337 sumHitrate 0.4264196697541281
#
# Time: Fri Sep 10 20:38:18 2021 --Episode: 4   Index: 90000   Loss: 0.033108994364738464   Reward: tensor(4.5330e-05, dtype=torch.float64)
# UEHitrate: 0.033899623337518475  edgeHitrate 0.3999955556049377 sumHitrate 0.4338951789424562
#
# Time: Fri Sep 10 20:39:01 2021 --Episode: 4   Index: 100000   Loss: 0.030761608853936195   Reward: tensor(4.0871e-05, dtype=torch.float64)
# UEHitrate: 0.03443965560344397  edgeHitrate 0.4045559544404556 sumHitrate 0.4389956100438996
#
# Time: Fri Sep 10 20:39:46 2021 --Episode: 4   Index: 110000   Loss: 0.02914930321276188   Reward: tensor(3.7350e-05, dtype=torch.float64)
# UEHitrate: 0.035717857110389904  edgeHitrate 0.4092780974718412 sumHitrate 0.44499595458223107
#
# Time: Fri Sep 10 20:40:27 2021 --Episode: 4   Index: 120000   Loss: 0.02783464640378952   Reward: tensor(3.4250e-05, dtype=torch.float64)
# UEHitrate: 0.036399696669194424  edgeHitrate 0.41374655211206574 sumHitrate 0.45014624878126014
#
# Time: Fri Sep 10 20:41:08 2021 --Episode: 4   Index: 130000   Loss: 0.026715295389294624   Reward: tensor(3.1832e-05, dtype=torch.float64)
# UEHitrate: 0.036330489765463346  edgeHitrate 0.4218890623918278 sumHitrate 0.4582195521572911
#
# Time: Fri Sep 10 20:41:48 2021 --Episode: 4   Index: 140000   Loss: 0.025706639513373375   Reward: tensor(2.9483e-05, dtype=torch.float64)
# UEHitrate: 0.035978314440611135  edgeHitrate 0.4268612367054521 sumHitrate 0.46283955114606323
#
# Time: Fri Sep 10 20:42:29 2021 --Episode: 4   Index: 150000   Loss: 0.025566400960087776   Reward: tensor(2.7358e-05, dtype=torch.float64)
# UEHitrate: 0.03592642715715229  edgeHitrate 0.43299044673035514 sumHitrate 0.4689168738875074
#
# Time: Fri Sep 10 20:43:09 2021 --Episode: 4   Index: 160000   Loss: 0.024745263159275055   Reward: tensor(2.5247e-05, dtype=torch.float64)
# UEHitrate: 0.035987275079530756  edgeHitrate 0.4403097480640746 sumHitrate 0.47629702314360534
#
# Time: Fri Sep 10 20:43:57 2021 --Episode: 4   Index: 170000   Loss: 0.02386530488729477   Reward: tensor(2.3661e-05, dtype=torch.float64)
# UEHitrate: 0.03566449609119946  edgeHitrate 0.4443209157593191 sumHitrate 0.4799854118505185
#
# ----------------------------------------------------------------
# Time: Fri Sep 10 20:44:05 2021 --End episode: 4   Loss: tensor(0.0236, device='cuda:1', grad_fn=<DivBackward0>)   Reward: tensor(2.3309e-05, dtype=torch.float64)
# UEHitrate: 0.035679581992633665  edgeHitrate 0.4453081815166732 sumHitrate 0.48098776350930683
# ----------------------------------------------------------------
#
# Time: Fri Sep 10 20:44:06 2021 --Episode: 5   Index: 0   Loss: 11.972171783447266   Reward: tensor(0., dtype=torch.float64)
# UEHitrate: 0.0  edgeHitrate 0.0 sumHitrate 0.0
#
# Time: Fri Sep 10 20:44:58 2021 --Episode: 5   Index: 10000   Loss: 0.06515110284090042   Reward: tensor(0.0002, dtype=torch.float64)
# UEHitrate: 0.0096990300969903  edgeHitrate 0.1444855514448555 sumHitrate 0.1541845815418458
#
# Time: Fri Sep 10 20:45:47 2021 --Episode: 5   Index: 20000   Loss: 0.11243683099746704   Reward: tensor(0.0002, dtype=torch.float64)
# UEHitrate: 0.013649317534123294  edgeHitrate 0.3086345682715864 sumHitrate 0.3222838858057097
#
# Time: Fri Sep 10 20:46:36 2021 --Episode: 5   Index: 30000   Loss: 0.10873199254274368   Reward: tensor(0.0002, dtype=torch.float64)
# UEHitrate: 0.020032665577814072  edgeHitrate 0.34198860037998735 sumHitrate 0.36202126595780143
#
# Time: Fri Sep 10 20:47:25 2021 --Episode: 5   Index: 40000   Loss: 0.09974520653486252   Reward: tensor(0.0001, dtype=torch.float64)
# UEHitrate: 0.02049948751281218  edgeHitrate 0.37614059648508785 sumHitrate 0.3966400839979001
#
# Time: Fri Sep 10 20:48:15 2021 --Episode: 5   Index: 50000   Loss: 0.08994705229997635   Reward: tensor(0.0001, dtype=torch.float64)
# UEHitrate: 0.02107957840843183  edgeHitrate 0.3872722545549089 sumHitrate 0.4083518329633407
#
# Time: Fri Sep 10 20:49:06 2021 --Episode: 5   Index: 60000   Loss: 0.07991184294223785   Reward: tensor(9.7040e-05, dtype=torch.float64)
# UEHitrate: 0.02094965083915268  edgeHitrate 0.39614339761003986 sumHitrate 0.41709304844919254
#
# Time: Fri Sep 10 20:50:03 2021 --Episode: 5   Index: 70000   Loss: 0.07056830823421478   Reward: tensor(8.6714e-05, dtype=torch.float64)
# UEHitrate: 0.02088541592262968  edgeHitrate 0.4084084513078385 sumHitrate 0.42929386723046814
#
# Time: Fri Sep 10 20:50:53 2021 --Episode: 5   Index: 80000   Loss: 0.06314535439014435   Reward: tensor(7.4824e-05, dtype=torch.float64)
# UEHitrate: 0.021499731253359335  edgeHitrate 0.41733228334645817 sumHitrate 0.4388320145998175
#
# Time: Fri Sep 10 20:51:42 2021 --Episode: 5   Index: 90000   Loss: 0.05739530920982361   Reward: tensor(6.6363e-05, dtype=torch.float64)
# UEHitrate: 0.021755313829846336  edgeHitrate 0.42063977066921476 sumHitrate 0.4423950844990611
#
# Time: Fri Sep 10 20:52:35 2021 --Episode: 5   Index: 100000   Loss: 0.05255407840013504   Reward: tensor(5.9570e-05, dtype=torch.float64)
# UEHitrate: 0.02209977900220998  edgeHitrate 0.42246577534224655 sumHitrate 0.44456555434445655
#
# Time: Fri Sep 10 20:53:36 2021 --Episode: 5   Index: 110000   Loss: 0.04883664473891258   Reward: tensor(5.4514e-05, dtype=torch.float64)
# UEHitrate: 0.02245434132416978  edgeHitrate 0.42211434441505075 sumHitrate 0.44456868573922054
#
# Time: Fri Sep 10 20:54:33 2021 --Episode: 5   Index: 120000   Loss: 0.04640701785683632   Reward: tensor(4.9834e-05, dtype=torch.float64)
# UEHitrate: 0.02283314305714119  edgeHitrate 0.42188815093207555 sumHitrate 0.4447212939892168
#
# Time: Fri Sep 10 20:55:25 2021 --Episode: 5   Index: 130000   Loss: 0.04502290114760399   Reward: tensor(4.6139e-05, dtype=torch.float64)
# UEHitrate: 0.02292290059307236  edgeHitrate 0.42589672387135485 sumHitrate 0.4488196244644272
#
# Time: Fri Sep 10 20:56:22 2021 --Episode: 5   Index: 140000   Loss: 0.04312003031373024   Reward: tensor(4.2901e-05, dtype=torch.float64)
# UEHitrate: 0.02286412239912572  edgeHitrate 0.4258398154298898 sumHitrate 0.4487039378290155
#
# Time: Fri Sep 10 20:57:13 2021 --Episode: 5   Index: 150000   Loss: 0.04132279008626938   Reward: tensor(3.9875e-05, dtype=torch.float64)
# UEHitrate: 0.02299984666768888  edgeHitrate 0.4244171705521963 sumHitrate 0.4474170172198852
#
# Time: Fri Sep 10 20:57:55 2021 --Episode: 5   Index: 160000   Loss: 0.04012840613722801   Reward: tensor(3.7055e-05, dtype=torch.float64)
# UEHitrate: 0.02339985375091406  edgeHitrate 0.42309735564152723 sumHitrate 0.4464972093924413
#
# Time: Fri Sep 10 20:58:39 2021 --Episode: 5   Index: 170000   Loss: 0.038543395698070526   Reward: tensor(3.4746e-05, dtype=torch.float64)
# UEHitrate: 0.023546920312233457  edgeHitrate 0.42002694101799404 sumHitrate 0.44357386133022747
#
# ----------------------------------------------------------------
# Time: Fri Sep 10 20:58:46 2021 --End episode: 5   Loss: tensor(0.0383, device='cuda:1', grad_fn=<DivBackward0>)   Reward: tensor(3.4268e-05, dtype=torch.float64)
# UEHitrate: 0.023681653409983534  edgeHitrate 0.42013696956296587 sumHitrate 0.4438186229729494
# ----------------------------------------------------------------
#
# Time: Fri Sep 10 20:58:46 2021 --Episode: 6   Index: 0   Loss: 24.882606506347656   Reward: tensor(0., dtype=torch.float64)
# UEHitrate: 0.0  edgeHitrate 0.0 sumHitrate 0.0
#
# Time: Fri Sep 10 20:59:26 2021 --Episode: 6   Index: 10000   Loss: 0.06026598811149597   Reward: tensor(0.0002, dtype=torch.float64)
# UEHitrate: 0.0093990600939906  edgeHitrate 0.1367863213678632 sumHitrate 0.1461853814618538
#
# Time: Fri Sep 10 21:00:07 2021 --Episode: 6   Index: 20000   Loss: 0.0633864551782608   Reward: tensor(0.0002, dtype=torch.float64)
# UEHitrate: 0.01544922753862307  edgeHitrate 0.2680865956702165 sumHitrate 0.2835358232088396
#
# Time: Fri Sep 10 21:00:56 2021 --Episode: 6   Index: 30000   Loss: 0.053586818277835846   Reward: tensor(0.0001, dtype=torch.float64)
# UEHitrate: 0.021699276690776974  edgeHitrate 0.32022265924469184 sumHitrate 0.3419219359354688
#
# Time: Fri Sep 10 21:01:41 2021 --Episode: 6   Index: 40000   Loss: 0.04686679318547249   Reward: tensor(0.0001, dtype=torch.float64)
# UEHitrate: 0.02532436689082773  edgeHitrate 0.35884102897427567 sumHitrate 0.3841653958651034
#
# Time: Fri Sep 10 21:02:20 2021 --Episode: 6   Index: 50000   Loss: 0.03997235745191574   Reward: tensor(8.7497e-05, dtype=torch.float64)
# UEHitrate: 0.0249595008099838  edgeHitrate 0.368892622147557 sumHitrate 0.39385212295754085
#
# Time: Fri Sep 10 21:03:01 2021 --Episode: 6   Index: 60000   Loss: 0.0349477156996727   Reward: tensor(7.4736e-05, dtype=torch.float64)
# UEHitrate: 0.024432926117898036  edgeHitrate 0.3738604356594057 sumHitrate 0.39829336177730373
#
# Time: Fri Sep 10 21:03:41 2021 --Episode: 6   Index: 70000   Loss: 0.03184427693486214   Reward: tensor(6.5526e-05, dtype=torch.float64)
# UEHitrate: 0.025328209597005758  edgeHitrate 0.391080127426751 sumHitrate 0.4164083370237568
#
# Time: Fri Sep 10 21:04:22 2021 --Episode: 6   Index: 80000   Loss: 0.02965635620057583   Reward: tensor(5.6951e-05, dtype=torch.float64)
# UEHitrate: 0.02627467156660542  edgeHitrate 0.4033574580317746 sumHitrate 0.42963212959838004
#
# Time: Fri Sep 10 21:05:04 2021 --Episode: 6   Index: 90000   Loss: 0.027934251353144646   Reward: tensor(5.1001e-05, dtype=torch.float64)
# UEHitrate: 0.026677481361318207  edgeHitrate 0.4085287941245097 sumHitrate 0.4352062754858279
#
# Time: Fri Sep 10 21:05:46 2021 --Episode: 6   Index: 100000   Loss: 0.026511942967772484   Reward: tensor(4.5888e-05, dtype=torch.float64)
# UEHitrate: 0.026899731002689973  edgeHitrate 0.4123058769412306 sumHitrate 0.43920560794392055
#
# Time: Fri Sep 10 21:06:25 2021 --Episode: 6   Index: 110000   Loss: 0.02528100274503231   Reward: tensor(4.2044e-05, dtype=torch.float64)
# UEHitrate: 0.02739066008490832  edgeHitrate 0.41595076408396287 sumHitrate 0.4433414241688712
#
# Time: Fri Sep 10 21:07:16 2021 --Episode: 6   Index: 120000   Loss: 0.02420872263610363   Reward: tensor(3.8531e-05, dtype=torch.float64)
# UEHitrate: 0.02777476854359547  edgeHitrate 0.41972983558470345 sumHitrate 0.44750460412829896
#
# Time: Fri Sep 10 21:08:00 2021 --Episode: 6   Index: 130000   Loss: 0.0231531523168087   Reward: tensor(3.5773e-05, dtype=torch.float64)
# UEHitrate: 0.027945938877393252  edgeHitrate 0.4274736348181937 sumHitrate 0.45541957369558694
#
# Time: Fri Sep 10 21:08:42 2021 --Episode: 6   Index: 140000   Loss: 0.022278359159827232   Reward: tensor(3.3076e-05, dtype=torch.float64)
# UEHitrate: 0.027549803215691317  edgeHitrate 0.4310969207362805 sumHitrate 0.45864672395197176
#
# Time: Fri Sep 10 21:09:23 2021 --Episode: 6   Index: 150000   Loss: 0.021496780216693878   Reward: tensor(3.0776e-05, dtype=torch.float64)
# UEHitrate: 0.02737315084566103  edgeHitrate 0.43504376637489084 sumHitrate 0.46241691722055184
#
# Time: Fri Sep 10 21:10:05 2021 --Episode: 6   Index: 160000   Loss: 0.020788220688700676   Reward: tensor(2.8616e-05, dtype=torch.float64)
# UEHitrate: 0.02758732757920263  edgeHitrate 0.43972225173592666 sumHitrate 0.4673095793151293
#
# Time: Fri Sep 10 21:10:45 2021 --Episode: 6   Index: 170000   Loss: 0.020308535546064377   Reward: tensor(2.6763e-05, dtype=torch.float64)
# UEHitrate: 0.027846895018264598  edgeHitrate 0.44219151652049105 sumHitrate 0.47003841153875564
#
# ----------------------------------------------------------------
# Time: Fri Sep 10 21:10:54 2021 --End episode: 6   Loss: tensor(0.0202, device='cuda:1', grad_fn=<DivBackward0>)   Reward: tensor(2.6366e-05, dtype=torch.float64)
# UEHitrate: 0.02790012975451377  edgeHitrate 0.4429341975876134 sumHitrate 0.47083432734212716
# ----------------------------------------------------------------
#
# Time: Fri Sep 10 21:10:54 2021 --Episode: 7   Index: 0   Loss: 90.89399719238281   Reward: tensor(0., dtype=torch.float64)
# UEHitrate: 0.0  edgeHitrate 0.0 sumHitrate 0.0
#
# Time: Fri Sep 10 21:11:33 2021 --Episode: 7   Index: 10000   Loss: 0.06257595866918564   Reward: tensor(0.0002, dtype=torch.float64)
# UEHitrate: 0.0093990600939906  edgeHitrate 0.13988601139886012 sumHitrate 0.14928507149285072
#
# Time: Fri Sep 10 21:12:17 2021 --Episode: 7   Index: 20000   Loss: 0.045453425496816635   Reward: tensor(0.0002, dtype=torch.float64)
# UEHitrate: 0.011699415029248537  edgeHitrate 0.1910404479776011 sumHitrate 0.20273986300684965
#
# Time: Fri Sep 10 21:12:59 2021 --Episode: 7   Index: 30000   Loss: 0.03575579449534416   Reward: tensor(0.0001, dtype=torch.float64)
# UEHitrate: 0.012732908903036565  edgeHitrate 0.21175960801306623 sumHitrate 0.2244925169161028
#
# Time: Fri Sep 10 21:13:40 2021 --Episode: 7   Index: 40000   Loss: 0.03135712444782257   Reward: tensor(9.6816e-05, dtype=torch.float64)
# UEHitrate: 0.014299642508937277  edgeHitrate 0.24346891327716808 sumHitrate 0.25776855578610536
#
# Time: Fri Sep 10 21:14:22 2021 --Episode: 7   Index: 50000   Loss: 0.027094578370451927   Reward: tensor(8.1483e-05, dtype=torch.float64)
# UEHitrate: 0.01651966960660787  edgeHitrate 0.26659466810663784 sumHitrate 0.28311433771324573
#
# Time: Fri Sep 10 21:15:07 2021 --Episode: 7   Index: 60000   Loss: 0.023837022483348846   Reward: tensor(6.9399e-05, dtype=torch.float64)
# UEHitrate: 0.018416359727337878  edgeHitrate 0.28619523007949865 sumHitrate 0.30461158980683656
#
# Time: Fri Sep 10 21:15:48 2021 --Episode: 7   Index: 70000   Loss: 0.021714068949222565   Reward: tensor(6.2039e-05, dtype=torch.float64)
# UEHitrate: 0.020942557963457665  edgeHitrate 0.3129955286353052 sumHitrate 0.3339380865987629
#
# Time: Fri Sep 10 21:16:30 2021 --Episode: 7   Index: 80000   Loss: 0.020131172612309456   Reward: tensor(5.4447e-05, dtype=torch.float64)
# UEHitrate: 0.022974712816089798  edgeHitrate 0.336083298958763 sumHitrate 0.3590580117748528
#
# Time: Fri Sep 10 21:17:12 2021 --Episode: 7   Index: 90000   Loss: 0.01892581209540367   Reward: tensor(4.8755e-05, dtype=torch.float64)
# UEHitrate: 0.024577504694392283  edgeHitrate 0.3519405339940667 sumHitrate 0.376518038688459
#
# Time: Fri Sep 10 21:17:56 2021 --Episode: 7   Index: 100000   Loss: 0.017817679792642593   Reward: tensor(4.4059e-05, dtype=torch.float64)
# UEHitrate: 0.025679743202567974  edgeHitrate 0.3634263657363426 sumHitrate 0.3891061089389106
#
# Time: Fri Sep 10 21:18:36 2021 --Episode: 7   Index: 110000   Loss: 0.016933327540755272   Reward: tensor(4.0394e-05, dtype=torch.float64)
# UEHitrate: 0.02691793710966264  edgeHitrate 0.373769329369733 sumHitrate 0.4006872664793956
#
# Time: Fri Sep 10 21:19:22 2021 --Episode: 7   Index: 120000   Loss: 0.016489537432789803   Reward: tensor(3.7246e-05, dtype=torch.float64)
# UEHitrate: 0.02780810159915334  edgeHitrate 0.38193015058207846 sumHitrate 0.40973825218123183
#
# Time: Fri Sep 10 21:20:08 2021 --Episode: 7   Index: 130000   Loss: 0.016024379059672356   Reward: tensor(3.4563e-05, dtype=torch.float64)
# UEHitrate: 0.0281997830785917  edgeHitrate 0.3925123652894978 sumHitrate 0.42071214836808946
#
# Time: Fri Sep 10 21:21:00 2021 --Episode: 7   Index: 140000   Loss: 0.01552189514040947   Reward: tensor(3.1949e-05, dtype=torch.float64)
# UEHitrate: 0.028449796787165808  edgeHitrate 0.39916857736730454 sumHitrate 0.42761837415447035
#
# Time: Fri Sep 10 21:21:56 2021 --Episode: 7   Index: 150000   Loss: 0.015126275829970837   Reward: tensor(2.9596e-05, dtype=torch.float64)
# UEHitrate: 0.028513143245711695  edgeHitrate 0.4067039553069646 sumHitrate 0.4352170985526763
#
# Time: Fri Sep 10 21:22:47 2021 --Episode: 7   Index: 160000   Loss: 0.014780435711145401   Reward: tensor(2.7418e-05, dtype=torch.float64)
# UEHitrate: 0.02897481890738183  edgeHitrate 0.41460365872713295 sumHitrate 0.4435784776345148
#
# Time: Fri Sep 10 21:23:29 2021 --Episode: 7   Index: 170000   Loss: 0.01464408915489912   Reward: tensor(2.5721e-05, dtype=torch.float64)
# UEHitrate: 0.029493944153269686  edgeHitrate 0.41935635672731336 sumHitrate 0.44885030088058303
#
# ----------------------------------------------------------------
# Time: Fri Sep 10 21:23:36 2021 --End episode: 7   Loss: tensor(0.0145, device='cuda:1', grad_fn=<DivBackward0>)   Reward: tensor(2.5317e-05, dtype=torch.float64)
# UEHitrate: 0.029575883116203024  edgeHitrate 0.42060827519594096 sumHitrate 0.450184158312144
# ----------------------------------------------------------------
#
# Time: Fri Sep 10 21:23:37 2021 --Episode: 8   Index: 0   Loss: 7.746868133544922   Reward: tensor(0., dtype=torch.float64)
# UEHitrate: 0.0  edgeHitrate 0.0 sumHitrate 0.0
#
# Time: Fri Sep 10 21:24:25 2021 --Episode: 8   Index: 10000   Loss: 0.04017513245344162   Reward: tensor(0.0003, dtype=torch.float64)
# UEHitrate: 0.0100989901009899  edgeHitrate 0.1454854514548545 sumHitrate 0.15558444155584442
#
# Time: Fri Sep 10 21:25:18 2021 --Episode: 8   Index: 20000   Loss: 0.04406006261706352   Reward: tensor(0.0003, dtype=torch.float64)
# UEHitrate: 0.014599270036498175  edgeHitrate 0.3025848707564622 sumHitrate 0.31718414079296037
#
# Time: Fri Sep 10 21:26:07 2021 --Episode: 8   Index: 30000   Loss: 0.03498405963182449   Reward: tensor(0.0002, dtype=torch.float64)
# UEHitrate: 0.016632778907369753  edgeHitrate 0.3526549115029499 sumHitrate 0.36928769041031967
#
# Time: Fri Sep 10 21:26:47 2021 --Episode: 8   Index: 40000   Loss: 0.03126820549368858   Reward: tensor(0.0002, dtype=torch.float64)
# UEHitrate: 0.016424589385265368  edgeHitrate 0.3813654658633534 sumHitrate 0.39779005524861877
#
# Time: Fri Sep 10 21:27:28 2021 --Episode: 8   Index: 50000   Loss: 0.02791636623442173   Reward: tensor(0.0001, dtype=torch.float64)
# UEHitrate: 0.01637967240655187  edgeHitrate 0.3906721865562689 sumHitrate 0.40705185896282076
#
# Time: Fri Sep 10 21:28:12 2021 --Episode: 8   Index: 60000   Loss: 0.026393210515379906   Reward: tensor(0.0001, dtype=torch.float64)
# UEHitrate: 0.017166380560323994  edgeHitrate 0.39569340510991485 sumHitrate 0.41285978567023884
#
# Time: Fri Sep 10 21:28:54 2021 --Episode: 8   Index: 70000   Loss: 0.024888096377253532   Reward: tensor(0.0001, dtype=torch.float64)
# UEHitrate: 0.018442593677233183  edgeHitrate 0.4071513264096227 sumHitrate 0.4255939200868559
#
# Time: Fri Sep 10 21:29:36 2021 --Episode: 8   Index: 80000   Loss: 0.023265479132533073   Reward: tensor(9.3231e-05, dtype=torch.float64)
# UEHitrate: 0.019374757815527305  edgeHitrate 0.4173197835027062 sumHitrate 0.43669454131823354
#
# Time: Fri Sep 10 21:30:22 2021 --Episode: 8   Index: 90000   Loss: 0.02209039218723774   Reward: tensor(8.4458e-05, dtype=torch.float64)
# UEHitrate: 0.019833112965411494  edgeHitrate 0.42383973511405426 sumHitrate 0.4436728480794658
#
# Time: Fri Sep 10 21:31:11 2021 --Episode: 8   Index: 100000   Loss: 0.02114086225628853   Reward: tensor(7.6278e-05, dtype=torch.float64)
# UEHitrate: 0.02012979870201298  edgeHitrate 0.4275857241427586 sumHitrate 0.44771552284477156
#
# Time: Fri Sep 10 21:32:00 2021 --Episode: 8   Index: 110000   Loss: 0.020498326048254967   Reward: tensor(6.9988e-05, dtype=torch.float64)
# UEHitrate: 0.020808901737256934  edgeHitrate 0.42939609639912363 sumHitrate 0.4502049981363806
#
# Time: Fri Sep 10 21:32:46 2021 --Episode: 8   Index: 120000   Loss: 0.02003418281674385   Reward: tensor(6.4526e-05, dtype=torch.float64)
# UEHitrate: 0.021399821668152765  edgeHitrate 0.4313130723910634 sumHitrate 0.45271289405921616
#
# Time: Fri Sep 10 21:33:36 2021 --Episode: 8   Index: 130000   Loss: 0.019454946741461754   Reward: tensor(5.9916e-05, dtype=torch.float64)
# UEHitrate: 0.021761371066376413  edgeHitrate 0.4375966338720471 sumHitrate 0.45935800493842355
#
# Time: Fri Sep 10 21:34:21 2021 --Episode: 8   Index: 140000   Loss: 0.018984589725732803   Reward: tensor(5.5741e-05, dtype=torch.float64)
# UEHitrate: 0.02212841336847594  edgeHitrate 0.44036114027756945 sumHitrate 0.4624895536460454
#
# Time: Fri Sep 10 21:35:06 2021 --Episode: 8   Index: 150000   Loss: 0.018529493361711502   Reward: tensor(5.1740e-05, dtype=torch.float64)
# UEHitrate: 0.022553182978780142  edgeHitrate 0.44415037233085114 sumHitrate 0.46670355530963126
#
# Time: Fri Sep 10 21:35:49 2021 --Episode: 8   Index: 160000   Loss: 0.01832066848874092   Reward: tensor(4.8219e-05, dtype=torch.float64)
# UEHitrate: 0.023393603789976312  edgeHitrate 0.446040962243986 sumHitrate 0.4694345660339623
#
# Time: Fri Sep 10 21:36:31 2021 --Episode: 8   Index: 170000   Loss: 0.018420927226543427   Reward: tensor(4.5141e-05, dtype=torch.float64)
# UEHitrate: 0.02382338927418074  edgeHitrate 0.4446326786313022 sumHitrate 0.4684560679054829
#
# ----------------------------------------------------------------
# Time: Fri Sep 10 21:36:38 2021 --End episode: 8   Loss: tensor(0.0184, device='cuda:1', grad_fn=<DivBackward0>)   Reward: tensor(4.4586e-05, dtype=torch.float64)
# UEHitrate: 0.02396094563693174  edgeHitrate 0.4445983137731798 sumHitrate 0.46855925941011156
# ----------------------------------------------------------------
#
# Time: Fri Sep 10 21:36:39 2021 --Episode: 9   Index: 0   Loss: 68.55435180664062   Reward: tensor(0., dtype=torch.float64)
# UEHitrate: 0.0  edgeHitrate 0.0 sumHitrate 0.0
#
# Time: Fri Sep 10 21:37:18 2021 --Episode: 9   Index: 10000   Loss: 0.06584107875823975   Reward: tensor(0.0003, dtype=torch.float64)
# UEHitrate: 0.0091990800919908  edgeHitrate 0.1192880711928807 sumHitrate 0.1284871512848715
#
# Time: Fri Sep 10 21:37:58 2021 --Episode: 9   Index: 20000   Loss: 0.0499354712665081   Reward: tensor(0.0002, dtype=torch.float64)
# UEHitrate: 0.012149392530373481  edgeHitrate 0.22453877306134692 sumHitrate 0.2366881655917204
#
# Time: Fri Sep 10 21:38:39 2021 --Episode: 9   Index: 30000   Loss: 0.03978501632809639   Reward: tensor(0.0002, dtype=torch.float64)
# UEHitrate: 0.014999500016666112  edgeHitrate 0.2919902669911003 sumHitrate 0.3069897670077664
#
# Time: Fri Sep 10 21:39:20 2021 --Episode: 9   Index: 40000   Loss: 0.033559735864400864   Reward: tensor(0.0002, dtype=torch.float64)
# UEHitrate: 0.01539961500962476  edgeHitrate 0.3444413889652759 sumHitrate 0.35984100397490065
#
# Time: Fri Sep 10 21:39:58 2021 --Episode: 9   Index: 50000   Loss: 0.029219016432762146   Reward: tensor(0.0002, dtype=torch.float64)
# UEHitrate: 0.01601967960640787  edgeHitrate 0.372112557748845 sumHitrate 0.3881322373552529
#
# Time: Fri Sep 10 21:40:38 2021 --Episode: 9   Index: 60000   Loss: 0.026715805754065514   Reward: tensor(0.0001, dtype=torch.float64)
# UEHitrate: 0.01636639389343511  edgeHitrate 0.3894268428859519 sumHitrate 0.405793236779387
#
# Time: Fri Sep 10 21:41:18 2021 --Episode: 9   Index: 70000   Loss: 0.025887927040457726   Reward: tensor(0.0001, dtype=torch.float64)
# UEHitrate: 0.018242596534335225  edgeHitrate 0.405908487021614 sumHitrate 0.4241510835559492
#
# Time: Fri Sep 10 21:42:01 2021 --Episode: 9   Index: 80000   Loss: 0.025263171643018723   Reward: tensor(0.0001, dtype=torch.float64)
# UEHitrate: 0.02019974750315621  edgeHitrate 0.4181197735028312 sumHitrate 0.4383195210059874
#
# Time: Fri Sep 10 21:42:43 2021 --Episode: 9   Index: 90000   Loss: 0.024890201166272163   Reward: tensor(9.4613e-05, dtype=torch.float64)
# UEHitrate: 0.021433095187831246  edgeHitrate 0.4258952678303574 sumHitrate 0.4473283630181887
#
# Time: Fri Sep 10 21:43:25 2021 --Episode: 9   Index: 100000   Loss: 0.024103360250592232   Reward: tensor(8.4297e-05, dtype=torch.float64)
# UEHitrate: 0.02195978040219598  edgeHitrate 0.4295157048429516 sumHitrate 0.4514754852451475
#
# Time: Fri Sep 10 21:44:07 2021 --Episode: 9   Index: 110000   Loss: 0.023174073547124863   Reward: tensor(7.6379e-05, dtype=torch.float64)
# UEHitrate: 0.022463432150616813  edgeHitrate 0.4296324578867465 sumHitrate 0.4520958900373633
#
# Time: Fri Sep 10 21:44:51 2021 --Episode: 9   Index: 120000   Loss: 0.02222895249724388   Reward: tensor(6.9717e-05, dtype=torch.float64)
# UEHitrate: 0.022408146598778343  edgeHitrate 0.42162981975150204 sumHitrate 0.4440379663502804
#
# Time: Fri Sep 10 21:45:31 2021 --Episode: 9   Index: 130000   Loss: 0.02186547964811325   Reward: tensor(6.4425e-05, dtype=torch.float64)
# UEHitrate: 0.022484442427365945  edgeHitrate 0.4160891070068692 sumHitrate 0.4385735494342351
#
# Time: Fri Sep 10 21:46:13 2021 --Episode: 9   Index: 140000   Loss: 0.02175593376159668   Reward: tensor(5.9817e-05, dtype=torch.float64)
# UEHitrate: 0.02257126734809037  edgeHitrate 0.41043992542910407 sumHitrate 0.43301119277719446
#
# Time: Fri Sep 10 21:46:52 2021 --Episode: 9   Index: 150000   Loss: 0.02154805324971676   Reward: tensor(5.5599e-05, dtype=torch.float64)
# UEHitrate: 0.02273318177878814  edgeHitrate 0.4073106179292138 sumHitrate 0.43004379970800194
#
# Time: Fri Sep 10 21:47:41 2021 --Episode: 9   Index: 160000   Loss: 0.021194247528910637   Reward: tensor(5.1706e-05, dtype=torch.float64)
# UEHitrate: 0.023306104336847894  edgeHitrate 0.40665995837526014 sumHitrate 0.4299660627121081
#
# Time: Fri Sep 10 21:48:34 2021 --Episode: 9   Index: 170000   Loss: 0.02103918418288231   Reward: tensor(4.8444e-05, dtype=torch.float64)
# UEHitrate: 0.023523391038876244  edgeHitrate 0.4039917412250516 sumHitrate 0.42751513226392784
#
# ----------------------------------------------------------------
# Time: Fri Sep 10 21:48:41 2021 --End episode: 9   Loss: tensor(0.0209, device='cuda:1', grad_fn=<DivBackward0>)   Reward: tensor(4.7897e-05, dtype=torch.float64)
# UEHitrate: 0.02365837905773785  edgeHitrate 0.4040369363970139 sumHitrate 0.42769531545475176
# ----------------------------------------------------------------
#
# Time: Fri Sep 10 21:48:42 2021 --Episode: 10   Index: 0   Loss: 11.210331916809082   Reward: tensor(0., dtype=torch.float64)
# UEHitrate: 0.0  edgeHitrate 0.0 sumHitrate 0.0
#
# Time: Fri Sep 10 21:49:24 2021 --Episode: 10   Index: 10000   Loss: 0.032537952065467834   Reward: tensor(0.0003, dtype=torch.float64)
# UEHitrate: 0.011398860113988602  edgeHitrate 0.1613838616138386 sumHitrate 0.17278272172782722
#
# Time: Fri Sep 10 21:50:05 2021 --Episode: 10   Index: 20000   Loss: 0.03830365836620331   Reward: tensor(0.0002, dtype=torch.float64)
# UEHitrate: 0.012449377531123443  edgeHitrate 0.216089195540223 sumHitrate 0.22853857307134642
#
# Time: Fri Sep 10 21:50:48 2021 --Episode: 10   Index: 30000   Loss: 0.03400559350848198   Reward: tensor(0.0002, dtype=torch.float64)
# UEHitrate: 0.013732875570814306  edgeHitrate 0.24262524582513917 sumHitrate 0.2563581213959535
#
# Time: Fri Sep 10 21:51:29 2021 --Episode: 10   Index: 40000   Loss: 0.029073651880025864   Reward: tensor(0.0002, dtype=torch.float64)
# UEHitrate: 0.014899627509312266  edgeHitrate 0.26949326266843326 sumHitrate 0.28439289017774555
#
# Time: Fri Sep 10 21:52:10 2021 --Episode: 10   Index: 50000   Loss: 0.02648138999938965   Reward: tensor(0.0001, dtype=torch.float64)
# UEHitrate: 0.016099678006439872  edgeHitrate 0.2763744725105498 sumHitrate 0.29247415051698966
#
# Time: Fri Sep 10 21:52:52 2021 --Episode: 10   Index: 60000   Loss: 0.023989569395780563   Reward: tensor(0.0001, dtype=torch.float64)
# UEHitrate: 0.016933051115814737  edgeHitrate 0.2875952067465542 sumHitrate 0.304528257862369
#
# Time: Fri Sep 10 21:53:32 2021 --Episode: 10   Index: 70000   Loss: 0.022290028631687164   Reward: tensor(9.6230e-05, dtype=torch.float64)
# UEHitrate: 0.018342595105784204  edgeHitrate 0.30315281210268424 sumHitrate 0.3214954072084685
#
# Time: Fri Sep 10 21:54:15 2021 --Episode: 10   Index: 80000   Loss: 0.02105434611439705   Reward: tensor(8.3810e-05, dtype=torch.float64)
# UEHitrate: 0.019699753753078086  edgeHitrate 0.31797102536218297 sumHitrate 0.33767077911526105
#
# Time: Fri Sep 10 21:54:57 2021 --Episode: 10   Index: 90000   Loss: 0.019617198035120964   Reward: tensor(7.5185e-05, dtype=torch.float64)
# UEHitrate: 0.020477550249441673  edgeHitrate 0.32647415028721904 sumHitrate 0.3469517005366607
#
# Time: Fri Sep 10 21:55:37 2021 --Episode: 10   Index: 100000   Loss: 0.018411003053188324   Reward: tensor(6.7709e-05, dtype=torch.float64)
# UEHitrate: 0.02094979050209498  edgeHitrate 0.3329866701332987 sumHitrate 0.35393646063539363
#
# Time: Fri Sep 10 21:56:18 2021 --Episode: 10   Index: 110000   Loss: 0.018129710108041763   Reward: tensor(6.1994e-05, dtype=torch.float64)
# UEHitrate: 0.021717984381960164  edgeHitrate 0.33797874564776687 sumHitrate 0.359696730029727
#
# Time: Fri Sep 10 21:56:59 2021 --Episode: 10   Index: 120000   Loss: 0.018060293048620224   Reward: tensor(5.7086e-05, dtype=torch.float64)
# UEHitrate: 0.022041482987641768  edgeHitrate 0.34342213814884875 sumHitrate 0.3654636211364905
#
# ...
# UEHitrate: 0.015010944322840857  edgeHitrate 0.29360784880168 sumHitrate 0.30861879312452084
#
# Time: Fri Sep 10 23:07:17 2021 --Episode: 16   Index: 100000   Loss: 0.024747924879193306   Reward: tensor(8.2257e-05, dtype=torch.float64)
# UEHitrate: 0.016419835801641983  edgeHitrate 0.3022469775302247 sumHitrate 0.3186668133318667
#
# Time: Fri Sep 10 23:07:54 2021 --Episode: 16   Index: 110000   Loss: 0.024430563673377037   Reward: tensor(7.5235e-05, dtype=torch.float64)
# UEHitrate: 0.01790892810065363  edgeHitrate 0.30866083035608766 sumHitrate 0.3265697584567413
#
# Time: Fri Sep 10 23:08:30 2021 --Episode: 16   Index: 120000   Loss: 0.023148218169808388   Reward: tensor(6.9273e-05, dtype=torch.float64)
# UEHitrate: 0.01916650694577545  edgeHitrate 0.31471404404963293 sumHitrate 0.33388055099540837
#
# Time: Fri Sep 10 23:09:05 2021 --Episode: 16   Index: 130000   Loss: 0.022191112861037254   Reward: tensor(6.4058e-05, dtype=torch.float64)
# UEHitrate: 0.019938308166860257  edgeHitrate 0.3252821132145137 sumHitrate 0.345220421381374
#
# Time: Fri Sep 10 23:09:38 2021 --Episode: 16   Index: 140000   Loss: 0.021849369630217552   Reward: tensor(5.9495e-05, dtype=torch.float64)
# UEHitrate: 0.020406997092877906  edgeHitrate 0.332961907414947 sumHitrate 0.35336890450782493
#
# Time: Fri Sep 10 23:10:10 2021 --Episode: 16   Index: 150000   Loss: 0.021842312067747116   Reward: tensor(5.5341e-05, dtype=torch.float64)
# UEHitrate: 0.02071319524536503  edgeHitrate 0.3413843907707282 sumHitrate 0.3620975860160932
#
# Time: Fri Sep 10 23:10:44 2021 --Episode: 16   Index: 160000   Loss: 0.021757418289780617   Reward: tensor(5.1619e-05, dtype=torch.float64)
# UEHitrate: 0.021356116524271725  edgeHitrate 0.3489353191542553 sumHitrate 0.370291435678527
#
# Time: Fri Sep 10 23:11:20 2021 --Episode: 16   Index: 170000   Loss: 0.021259695291519165   Reward: tensor(4.8378e-05, dtype=torch.float64)
# UEHitrate: 0.022058693772389573  edgeHitrate 0.3533920388703596 sumHitrate 0.37545073264274914
#
# ----------------------------------------------------------------
# Time: Fri Sep 10 23:11:26 2021 --End episode: 16   Loss: tensor(0.0211, device='cuda:1', grad_fn=<DivBackward0>)   Reward: tensor(4.7806e-05, dtype=torch.float64)
# UEHitrate: 0.022151364749829806  edgeHitrate 0.35461966799136524 sumHitrate 0.376771032741195
# ----------------------------------------------------------------
#
# Time: Fri Sep 10 23:11:26 2021 --Episode: 17   Index: 0   Loss: 76.38204956054688   Reward: tensor(0., dtype=torch.float64)
# UEHitrate: 0.0  edgeHitrate 0.0 sumHitrate 0.0
#
# Time: Fri Sep 10 23:12:00 2021 --Episode: 17   Index: 10000   Loss: 0.04476995766162872   Reward: tensor(0.0004, dtype=torch.float64)
# UEHitrate: 0.011498850114988501  edgeHitrate 0.21397860213978603 sumHitrate 0.22547745225477453
#
# Time: Fri Sep 10 23:12:32 2021 --Episode: 17   Index: 20000   Loss: 0.034193072468042374   Reward: tensor(0.0003, dtype=torch.float64)
# UEHitrate: 0.012099395030248488  edgeHitrate 0.25218739063046847 sumHitrate 0.26428678566071695
#
# Time: Fri Sep 10 23:13:05 2021 --Episode: 17   Index: 30000   Loss: 0.02911798469722271   Reward: tensor(0.0002, dtype=torch.float64)
# UEHitrate: 0.01316622779240692  edgeHitrate 0.283557214759508 sumHitrate 0.29672344255191496
#
# Time: Fri Sep 10 23:13:38 2021 --Episode: 17   Index: 40000   Loss: 0.026113485917448997   Reward: tensor(0.0002, dtype=torch.float64)
# UEHitrate: 0.013249668758281043  edgeHitrate 0.30999225019374516 sumHitrate 0.3232419189520262
#
# Time: Fri Sep 10 23:14:14 2021 --Episode: 17   Index: 50000   Loss: 0.023188237100839615   Reward: tensor(0.0001, dtype=torch.float64)
# UEHitrate: 0.014059718805623888  edgeHitrate 0.31803363932721346 sumHitrate 0.33209335813283736
#
# Time: Fri Sep 10 23:14:49 2021 --Episode: 17   Index: 60000   Loss: 0.021247949451208115   Reward: tensor(0.0001, dtype=torch.float64)
# UEHitrate: 0.014883085281911968  edgeHitrate 0.3224779587006883 sumHitrate 0.3373610439826003
#
# Time: Fri Sep 10 23:15:22 2021 --Episode: 17   Index: 70000   Loss: 0.019100705161690712   Reward: tensor(0.0001, dtype=torch.float64)
# UEHitrate: 0.015714061227696748  edgeHitrate 0.33245239353723516 sumHitrate 0.3481664547649319
#
# Time: Fri Sep 10 23:15:55 2021 --Episode: 17   Index: 80000   Loss: 0.01846659928560257   Reward: tensor(8.7847e-05, dtype=torch.float64)
# UEHitrate: 0.016712291096361295  edgeHitrate 0.3407832402094974 sumHitrate 0.35749553130585865
#
# Time: Fri Sep 10 23:16:28 2021 --Episode: 17   Index: 90000   Loss: 0.018246443942189217   Reward: tensor(7.8900e-05, dtype=torch.float64)
# UEHitrate: 0.017288696792257863  edgeHitrate 0.3446850590548994 sumHitrate 0.36197375584715724
#
# Time: Fri Sep 10 23:17:01 2021 --Episode: 17   Index: 100000   Loss: 0.01817537285387516   Reward: tensor(7.1133e-05, dtype=torch.float64)
# UEHitrate: 0.01826981730182698  edgeHitrate 0.34968650313496863 sumHitrate 0.36795632043679566
#
# Time: Fri Sep 10 23:17:35 2021 --Episode: 17   Index: 110000   Loss: 0.01749255694448948   Reward: tensor(6.5225e-05, dtype=torch.float64)
# UEHitrate: 0.01929073372060254  edgeHitrate 0.35308769920273453 sumHitrate 0.37237843292333705
#
# Time: Fri Sep 10 23:18:09 2021 --Episode: 17   Index: 120000   Loss: 0.01662292517721653   Reward: tensor(5.9946e-05, dtype=torch.float64)
# UEHitrate: 0.020183165140290497  edgeHitrate 0.35608036599695003 sumHitrate 0.37626353113724054
#
# Time: Fri Sep 10 23:18:42 2021 --Episode: 17   Index: 130000   Loss: 0.016053641214966774   Reward: tensor(5.5701e-05, dtype=torch.float64)
# UEHitrate: 0.020584457042638133  edgeHitrate 0.36242798132322057 sumHitrate 0.38301243836585874
#
# Time: Fri Sep 10 23:19:15 2021 --Episode: 17   Index: 140000   Loss: 0.01574642024934292   Reward: tensor(5.1760e-05, dtype=torch.float64)
# UEHitrate: 0.02079270862350983  edgeHitrate 0.36587595802887124 sumHitrate 0.38666866665238103
#
# Time: Fri Sep 10 23:19:49 2021 --Episode: 17   Index: 150000   Loss: 0.01584923081099987   Reward: tensor(4.8162e-05, dtype=torch.float64)
# UEHitrate: 0.021019859867600882  edgeHitrate 0.37051752988313413 sumHitrate 0.391537389750735
#
# Time: Fri Sep 10 23:20:21 2021 --Episode: 17   Index: 160000   Loss: 0.015595554374158382   Reward: tensor(4.4788e-05, dtype=torch.float64)
# UEHitrate: 0.02153111543052856  edgeHitrate 0.37607264954594033 sumHitrate 0.3976037649764689
#
# Time: Fri Sep 10 23:20:54 2021 --Episode: 17   Index: 170000   Loss: 0.015924477949738503   Reward: tensor(4.2002e-05, dtype=torch.float64)
# UEHitrate: 0.022199869412532866  edgeHitrate 0.3785271851342051 sumHitrate 0.40072705454673796
#
# ----------------------------------------------------------------
# Time: Fri Sep 10 23:21:00 2021 --End episode: 17   Loss: tensor(0.0159, device='cuda:1', grad_fn=<DivBackward0>)   Reward: tensor(4.1463e-05, dtype=torch.float64)
# UEHitrate: 0.022244462158812543  edgeHitrate 0.3792788441956675 sumHitrate 0.40152330635448
# ----------------------------------------------------------------
#
# Time: Fri Sep 10 23:21:01 2021 --Episode: 18   Index: 0   Loss: 22.99628448486328   Reward: tensor(0., dtype=torch.float64)
# UEHitrate: 0.0  edgeHitrate 0.0 sumHitrate 0.0
#
# Time: Fri Sep 10 23:21:32 2021 --Episode: 18   Index: 10000   Loss: 0.033565931022167206   Reward: tensor(0.0004, dtype=torch.float64)
# UEHitrate: 0.0117988201179882  edgeHitrate 0.2211778822117788 sumHitrate 0.23297670232976703
#
# Time: Fri Sep 10 23:22:04 2021 --Episode: 18   Index: 20000   Loss: 0.03952943906188011   Reward: tensor(0.0003, dtype=torch.float64)
# UEHitrate: 0.012899355032248387  edgeHitrate 0.2392880355982201 sumHitrate 0.25218739063046847
#
# Time: Fri Sep 10 23:22:36 2021 --Episode: 18   Index: 30000   Loss: 0.033694103360176086   Reward: tensor(0.0002, dtype=torch.float64)
# UEHitrate: 0.013199560014666177  edgeHitrate 0.2581247291756941 sumHitrate 0.27132428919036033
#
# Time: Fri Sep 10 23:23:08 2021 --Episode: 18   Index: 40000   Loss: 0.03345627710223198   Reward: tensor(0.0002, dtype=torch.float64)
# UEHitrate: 0.014424639384015399  edgeHitrate 0.2747181320466988 sumHitrate 0.2891427714307142
#
# Time: Fri Sep 10 23:23:43 2021 --Episode: 18   Index: 50000   Loss: 0.03167707473039627   Reward: tensor(0.0002, dtype=torch.float64)
# UEHitrate: 0.01733965320693586  edgeHitrate 0.29619407611847764 sumHitrate 0.3135337293254135
#
# Time: Fri Sep 10 23:24:16 2021 --Episode: 18   Index: 60000   Loss: 0.03204616159200668   Reward: tensor(0.0002, dtype=torch.float64)
# UEHitrate: 0.01933301111648139  edgeHitrate 0.3039282678622023 sumHitrate 0.3232612789786837
#
# Time: Fri Sep 10 23:24:50 2021 --Episode: 18   Index: 70000   Loss: 0.029352134093642235   Reward: tensor(0.0002, dtype=torch.float64)
# UEHitrate: 0.020099712861244838  edgeHitrate 0.3127383894515793 sumHitrate 0.3328381023128241
#
# Time: Fri Sep 10 23:25:22 2021 --Episode: 18   Index: 80000   Loss: 0.027435332536697388   Reward: tensor(0.0001, dtype=torch.float64)
# UEHitrate: 0.02068724140948238  edgeHitrate 0.3228709641129486 sumHitrate 0.343558205522431
#
# Time: Fri Sep 10 23:25:57 2021 --Episode: 18   Index: 90000   Loss: 0.02631162479519844   Reward: tensor(0.0001, dtype=torch.float64)
# UEHitrate: 0.02075532494083399  edgeHitrate 0.3309185453494961 sumHitrate 0.3516738702903301
#
# Time: Fri Sep 10 23:26:30 2021 --Episode: 18   Index: 100000   Loss: 0.025518549606204033   Reward: tensor(0.0001, dtype=torch.float64)
# UEHitrate: 0.02046979530204698  edgeHitrate 0.33486665133348664 sumHitrate 0.35533644663553365
#
# Time: Fri Sep 10 23:27:04 2021 --Episode: 18   Index: 110000   Loss: 0.025020010769367218   Reward: tensor(0.0001, dtype=torch.float64)
# UEHitrate: 0.020172543885964674  edgeHitrate 0.3280515631676076 sumHitrate 0.34822410705357226
#
# Time: Fri Sep 10 23:27:38 2021 --Episode: 18   Index: 120000   Loss: 0.02536279521882534   Reward: tensor(0.0001, dtype=torch.float64)
# UEHitrate: 0.019741502154148716  edgeHitrate 0.3132223898134182 sumHitrate 0.3329638919675669
#
# Time: Fri Sep 10 23:28:13 2021 --Episode: 18   Index: 130000   Loss: 0.026008618995547295   Reward: tensor(9.9818e-05, dtype=torch.float64)
# UEHitrate: 0.0189998538472781  edgeHitrate 0.2981207836862793 sumHitrate 0.31712063753355746
#
# Time: Fri Sep 10 23:28:46 2021 --Episode: 18   Index: 140000   Loss: 0.026978280395269394   Reward: tensor(9.4658e-05, dtype=torch.float64)
# UEHitrate: 0.018199870000928566  edgeHitrate 0.28309083506546384 sumHitrate 0.3012907050663924
#
# Time: Fri Sep 10 23:29:19 2021 --Episode: 18   Index: 150000   Loss: 0.028176218271255493   Reward: tensor(8.9513e-05, dtype=torch.float64)
# UEHitrate: 0.017579882800781328  edgeHitrate 0.26993153378977475 sumHitrate 0.28751141659055607
#
# Time: Fri Sep 10 23:29:52 2021 --Episode: 18   Index: 160000   Loss: 0.028616243973374367   Reward: tensor(8.3285e-05, dtype=torch.float64)
# UEHitrate: 0.017293641914738034  edgeHitrate 0.25837963512728046 sumHitrate 0.2756732770420185
#
# Time: Fri Sep 10 23:30:26 2021 --Episode: 18   Index: 170000   Loss: 0.030252665281295776   Reward: tensor(8.0277e-05, dtype=torch.float64)
# UEHitrate: 0.01713519332239222  edgeHitrate 0.24938676831312756 sumHitrate 0.2665219616355198
#
# ----------------------------------------------------------------
# Time: Fri Sep 10 23:30:32 2021 --End episode: 18   Loss: tensor(0.0303, device='cuda:1', grad_fn=<DivBackward0>)   Reward: tensor(7.8023e-05, dtype=torch.float64)
# UEHitrate: 0.017159016193130577  edgeHitrate 0.2493730471363819 sumHitrate 0.26653206332951246
# ----------------------------------------------------------------
#
# Time: Fri Sep 10 23:30:32 2021 --Episode: 19   Index: 0   Loss: 26.80811309814453   Reward: tensor(0., dtype=torch.float64)
# UEHitrate: 0.0  edgeHitrate 0.0 sumHitrate 0.0
#
# Time: Fri Sep 10 23:31:04 2021 --Episode: 19   Index: 10000   Loss: 0.20613056421279907   Reward: tensor(0.0004, dtype=torch.float64)
# UEHitrate: 0.0112988701129887  edgeHitrate 0.19718028197180282 sumHitrate 0.2084791520847915
#
# Time: Fri Sep 10 23:31:37 2021 --Episode: 19   Index: 20000   Loss: 0.17661863565444946   Reward: tensor(0.0003, dtype=torch.float64)
# UEHitrate: 0.0135993200339983  edgeHitrate 0.2504374781260937 sumHitrate 0.264036798160092
#
# Time: Fri Sep 10 23:32:10 2021 --Episode: 19   Index: 30000   Loss: 0.1350318193435669   Reward: tensor(0.0002, dtype=torch.float64)
# UEHitrate: 0.01823272557581414  edgeHitrate 0.2853238225392487 sumHitrate 0.30355654811506283
#
# Time: Fri Sep 10 23:32:46 2021 --Episode: 19   Index: 40000   Loss: 0.11158017069101334   Reward: tensor(0.0002, dtype=torch.float64)
# UEHitrate: 0.020099497512562185  edgeHitrate 0.31101722456938574 sumHitrate 0.331116722081948
#
# Time: Fri Sep 10 23:33:21 2021 --Episode: 19   Index: 50000   Loss: 0.09513209015130997   Reward: tensor(0.0002, dtype=torch.float64)
# UEHitrate: 0.021619567608647826  edgeHitrate 0.31737365252694943 sumHitrate 0.3389932201355973
#
# Time: Fri Sep 10 23:33:55 2021 --Episode: 19   Index: 60000   Loss: 0.08250894397497177   Reward: tensor(0.0001, dtype=torch.float64)
# UEHitrate: 0.022599623339611005  edgeHitrate 0.3222612956450726 sumHitrate 0.3448609189846836
#
# Time: Fri Sep 10 23:34:29 2021 --Episode: 19   Index: 70000   Loss: 0.07316082715988159   Reward: tensor(0.0001, dtype=torch.float64)
# UEHitrate: 0.02407108469879002  edgeHitrate 0.3320238282310253 sumHitrate 0.35609491292981527
#
# Time: Fri Sep 10 23:35:03 2021 --Episode: 19   Index: 80000   Loss: 0.06570105999708176   Reward: tensor(9.5718e-05, dtype=torch.float64)
# UEHitrate: 0.024962187972650342  edgeHitrate 0.34217072286596417 sumHitrate 0.3671329108386145
#
# Time: Fri Sep 10 23:35:37 2021 --Episode: 19   Index: 90000   Loss: 0.05977141484618187   Reward: tensor(8.6021e-05, dtype=torch.float64)
# UEHitrate: 0.025766380373551404  edgeHitrate 0.3463183742402862 sumHitrate 0.3720847546138376
#
# Time: Fri Sep 10 23:36:12 2021 --Episode: 19   Index: 100000   Loss: 0.054949816316366196   Reward: tensor(7.7361e-05, dtype=torch.float64)
# UEHitrate: 0.026269737302626973  edgeHitrate 0.3490665093349066 sumHitrate 0.3753362466375336
#
# Time: Fri Sep 10 23:36:45 2021 --Episode: 19   Index: 110000   Loss: 0.05094157159328461   Reward: tensor(7.1022e-05, dtype=torch.float64)
# UEHitrate: 0.026263397605476312  edgeHitrate 0.3511695348224107 sumHitrate 0.377432932427887
#
# Time: Fri Sep 10 23:37:18 2021 --Episode: 19   Index: 120000   Loss: 0.04805203899741173   Reward: tensor(6.5495e-05, dtype=torch.float64)
# UEHitrate: 0.026166448612928224  edgeHitrate 0.35360538662177815 sumHitrate 0.37977183523470637
#
# Time: Fri Sep 10 23:37:55 2021 --Episode: 19   Index: 130000   Loss: 0.04570462927222252   Reward: tensor(6.0797e-05, dtype=torch.float64)
# UEHitrate: 0.025930569764847963  edgeHitrate 0.3590664687194714 sumHitrate 0.3849970384843194
#
# Time: Fri Sep 10 23:38:29 2021 --Episode: 19   Index: 140000   Loss: 0.043402284383773804   Reward: tensor(5.6373e-05, dtype=torch.float64)
# UEHitrate: 0.025514103470689494  edgeHitrate 0.36056171027349804 sumHitrate 0.38607581374418753
#
# Time: Fri Sep 10 23:39:02 2021 --Episode: 19   Index: 150000   Loss: 0.041203610599040985   Reward: tensor(5.2495e-05, dtype=torch.float64)
# UEHitrate: 0.02539983066779555  edgeHitrate 0.3636709088606076 sumHitrate 0.38907073952840315
#
# Time: Fri Sep 10 23:39:34 2021 --Episode: 19   Index: 160000   Loss: 0.039245717227458954   Reward: tensor(4.8862e-05, dtype=torch.float64)
# UEHitrate: 0.025368591446303462  edgeHitrate 0.36772270173311417 sumHitrate 0.39309129317941766
#
# Time: Fri Sep 10 23:40:09 2021 --Episode: 19   Index: 170000   Loss: 0.037671662867069244   Reward: tensor(4.5711e-05, dtype=torch.float64)
# UEHitrate: 0.025399850589114183  edgeHitrate 0.36933900388821245 sumHitrate 0.3947388544773266
#
# ----------------------------------------------------------------
# Time: Fri Sep 10 23:40:16 2021 --End episode: 19   Loss: tensor(0.0373, device='cuda:1', grad_fn=<DivBackward0>)   Reward: tensor(4.5064e-05, dtype=torch.float64)
# UEHitrate: 0.025421411240348416  edgeHitrate 0.3700447449421923 sumHitrate 0.3954661561825407
# ----------------------------------------------------------------
